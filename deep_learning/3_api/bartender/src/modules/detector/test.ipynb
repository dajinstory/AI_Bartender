# %%
from Detector import Detector
import cv2
import matplotlib.pyplot as plt

# %%
detector=Detector()

# %%
image = cv2.imread('../../../../../images/2.jpg', cv2.IMREAD_COLOR)

# %%
plt.imshow(image)
image.shape
# Out:
# (720, 1280, 3)

# %%
result = detector.get_objects(image)
# Out:
# 5/5 [==============================] - 4s 783ms/step

# %%
result
# Out:
# [{'x': 219, 'y': 154, 'len_x': 195, 'len_y': 598, 'label': 'Person'},
#  {'x': 93, 'y': 640, 'len_x': 62, 'len_y': 556, 'label': 'Bottle'},
#  {'x': 0, 'y': 671, 'len_x': 125, 'len_y': 607, 'label': 'Person'},
#  {'x': 383, 'y': 689, 'len_x': 46, 'len_y': 538, 'label': 'Bottle'},
#  {'x': 451, 'y': 679, 'len_x': 48, 'len_y': 549, 'label': 'Bottle'},
#  {'x': 415, 'y': 685, 'len_x': 46, 'len_y': 546, 'label': 'Bottle'},
#  {'x': 521, 'y': 696, 'len_x': 49, 'len_y': 523, 'label': 'Bottle'},
#  {'x': 558, 'y': 776, 'len_x': 38, 'len_y': 458, 'label': 'Bottle'},
#  {'x': 190, 'y': 645, 'len_x': 52, 'len_y': 544, 'label': 'Bottle'},
#  {'x': 477, 'y': 625, 'len_x': 61, 'len_y': 578, 'label': 'Bottle'},
#  {'x': 531, 'y': 0, 'len_x': 149, 'len_y': 552, 'label': 'Person'},
#  {'x': 375, 'y': 128, 'len_x': 52, 'len_y': 444, 'label': 'Bottle'},
#  {'x': 307, 'y': 612, 'len_x': 38, 'len_y': 644, 'label': 'Bottle'},
#  {'x': 564, 'y': 74, 'len_x': 68, 'len_y': 571, 'label': 'Bottle'},
# ...

# %%
for i in range(len(result)):
    target = image[ result[i]['y']:result[i]['y']+result[i]['len_y'] , result[i]['y']:result[i]['y']+result[i]['len_y']]
    plt.imshow(target)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-88e168125bac> in <module>
#       1 for i in range(len(result)):
#       2     target = image[ result[i]['y']:result[i]['y']+result[i]['len_y'] , result[i]['y']:result[i]['y']+result[i]['len_y']]
# ----> 3     plt.imshow(target)
#       4     plt.show()
#
# ~\Anaconda3\envs\ai_bartender\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# ...
