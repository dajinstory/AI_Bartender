# %%
from Detector import Detector
import cv2
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
detector=Detector()
# Out:
# WARNING:tensorflow:From /Users/dajinhan/anaconda3/envs/ai_bartender/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
image = cv2.imread('../../../../../images/1.jpg', cv2.IMREAD_COLOR)

# %%
image_resized = cv2.resize(image, (300,300))

# %%
plt.imshow(image)

# %%
result = detector.get_objects(image)
# Out:
# 70/70 [==============================] - 46s 654ms/step

# %%
result
# Out:
# [{'r': 360, 'c': 9, 'len_r': 102, 'len_c': 81, 'label': 'Bottle'},
#  {'r': 360, 'c': 148, 'len_r': 103, 'len_c': 66, 'label': 'Bottle'},
#  {'r': 0, 'c': 20, 'len_r': 104, 'len_c': 68, 'label': 'Bottle'},
#  {'r': 360, 'c': 785, 'len_r': 104, 'len_c': 60, 'label': 'Bottle'},
#  {'r': 361, 'c': 644, 'len_r': 102, 'len_c': 65, 'label': 'Bottle'},
#  {'r': 2, 'c': 640, 'len_r': 101, 'len_c': 54, 'label': 'Bottle'},
#  {'r': 365, 'c': 313, 'len_r': 97, 'len_c': 58, 'label': 'Bottle'},
#  {'r': 74, 'c': 360, 'len_r': 102, 'len_c': 73, 'label': 'Bottle'},
#  {'r': 0, 'c': 232, 'len_r': 174, 'len_c': 72, 'label': 'Bottle'},
#  {'r': 363, 'c': 572, 'len_r': 100, 'len_c': 78, 'label': 'Bottle'},
#  {'r': 288, 'c': 414, 'len_r': 104, 'len_c': 143, 'label': 'Bottle'},
#  {'r': 73, 'c': 770, 'len_r': 100, 'len_c': 83, 'label': 'Bottle'},
#  {'r': 291, 'c': 785, 'len_r': 99, 'len_c': 39, 'label': 'Bottle'},
#  {'r': 290, 'c': 6, 'len_r': 101, 'len_c': 88, 'label': 'Bottle'},
#  {'r': 0, 'c': 437, 'len_r': 173, 'len_c': 64, 'label': 'Bottle'},
#  {'r': 242, 'c': 853, 'len_r': 46, 'len_c': 99, 'label': 'Tvmonitor'},
#  {'r': 363, 'c': 216, 'len_r': 148, 'len_c': 63, 'label': 'Bottle'},
#  {'r': 19, 'c': 781, 'len_r': 85, 'len_c': 43, 'label': 'Bottle'},
#  {'r': 433, 'c': 644, 'len_r': 99, 'len_c': 71, 'label': 'Bottle'},
#  {'r': 1, 'c': 910, 'len_r': 101, 'len_c': 41, 'label': 'Bottle'},
#  {'r': 5, 'c': 512, 'len_r': 96, 'len_c': 53, 'label': 'Bottle'},
#  {'r': 72, 'c': 627, 'len_r': 102, 'len_c': 69, 'label': 'Bottle'},
#  {'r': 75, 'c': 566, 'len_r': 97, 'len_c': 70, 'label': 'Bottle'},
#  {'r': 75, 'c': 701, 'len_r': 98, 'len_c': 76, 'label': 'Bottle'},
#  {'r': 24, 'c': 906, 'len_r': 144, 'len_c': 50, 'label': 'Bottle'},
#  {'r': 4, 'c': 575, 'len_r': 99, 'len_c': 57, 'label': 'Bottle'},
#  {'r': 361, 'c': 448, 'len_r': 101, 'len_c': 77, 'label': 'Bottle'},
#  {'r': 432, 'c': 776, 'len_r': 92, 'len_c': 61, 'label': 'Bottle'},
#  {'r': 435, 'c': 11, 'len_r': 95, 'len_c': 69, 'label': 'Bottle'},
#  {'r': 288, 'c': 157, 'len_r': 103, 'len_c': 60, 'label': 'Bottle'},
#  {'r': 292, 'c': 211, 'len_r': 124, 'len_c': 61, 'label': 'Bottle'},
#  {'r': 7, 'c': 773, 'len_r': 95, 'len_c': 77, 'label': 'Bottle'},
#  {'r': 0, 'c': 652, 'len_r': 159, 'len_c': 50, 'label': 'Bottle'},
#  {'r': 245, 'c': 434, 'len_r': 39, 'len_c': 79, 'label': 'Tvmonitor'},
#  {'r': 307, 'c': 787, 'len_r': 109, 'len_c': 50, 'label': 'Bottle'},
#  {'r': 290, 'c': 643, 'len_r': 100, 'len_c': 64, 'label': 'Bottle'},
#  {'r': 298, 'c': 4, 'len_r': 197, 'len_c': 74, 'label': 'Bottle'},
#  {'r': 433, 'c': 151, 'len_r': 81, 'len_c': 60, 'label': 'Bottle'},
#  {'r': 360, 'c': 79, 'len_r': 104, 'len_c': 77, 'label': 'Bottle'},
#  {'r': 74, 'c': 291, 'len_r': 102, 'len_c': 87, 'label': 'Bottle'},
#  {'r': 0, 'c': 7, 'len_r': 226, 'len_c': 84, 'label': 'Bottle'},
#  {'r': 2, 'c': 708, 'len_r': 100, 'len_c': 59, 'label': 'Bottle'},
#  {'r': 245, 'c': 128, 'len_r': 64, 'len_c': 184, 'label': 'Car'},
#  {'r': 360, 'c': 518, 'len_r': 104, 'len_c': 75, 'label': 'Bottle'},
#  {'r': 287, 'c': 312, 'len_r': 129, 'len_c': 68, 'label': 'Bottle'},
#  {'r': 363, 'c': 908, 'len_r': 98, 'len_c': 42, 'label': 'Bottle'},
#  {'r': 432, 'c': 586, 'len_r': 104, 'len_c': 58, 'label': 'Bottle'},
#  {'r': 3, 'c': 89, 'len_r': 101, 'len_c': 68, 'label': 'Bottle'},
#  {'r': 304, 'c': 84, 'len_r': 112, 'len_c': 65, 'label': 'Bottle'},
#  {'r': 310, 'c': 914, 'len_r': 105, 'len_c': 40, 'label': 'Bottle'},
#  {'r': 294, 'c': 513, 'len_r': 96, 'len_c': 138, 'label': 'Bottle'},
#  {'r': 288, 'c': 28, 'len_r': 201, 'len_c': 87, 'label': 'Bottle'},
#  {'r': 288, 'c': 278, 'len_r': 102, 'len_c': 154, 'label': 'Bottle'},
#  {'r': 24, 'c': 846, 'len_r': 143, 'len_c': 53, 'label': 'Bottle'},
#  {'r': 72, 'c': 50, 'len_r': 104, 'len_c': 119, 'label': 'Bottle'},
#  {'r': 433, 'c': 128, 'len_r': 59, 'len_c': 28, 'label': 'Bottle'},
#  {'r': 363, 'c': 664, 'len_r': 174, 'len_c': 58, 'label': 'Bottle'},
#  {'r': 436, 'c': 315, 'len_r': 96, 'len_c': 62, 'label': 'Bottle'},
#  {'r': 360, 'c': 384, 'len_r': 104, 'len_c': 61, 'label': 'Bottle'},
#  {'r': 360, 'c': 696, 'len_r': 104, 'len_c': 81, 'label': 'Bottle'},
#  {'r': 280, 'c': 541, 'len_r': 261, 'len_c': 82, 'label': 'Bottle'},
#  {'r': 14, 'c': 485, 'len_r': 197, 'len_c': 73, 'label': 'Bottle'},
#  {'r': 292, 'c': 838, 'len_r': 97, 'len_c': 56, 'label': 'Bottle'},
#  {'r': 433, 'c': 681, 'len_r': 100, 'len_c': 100, 'label': 'Bottle'},
#  {'r': 295, 'c': 452, 'len_r': 110, 'len_c': 70, 'label': 'Bottle'},
#  {'r': 0, 'c': 161, 'len_r': 104, 'len_c': 94, 'label': 'Bottle'},
#  {'r': 308, 'c': 854, 'len_r': 107, 'len_c': 47, 'label': 'Bottle'},
#  {'r': 248, 'c': 18, 'len_r': 47, 'len_c': 282, 'label': 'Car'},
#  {'r': 246, 'c': 768, 'len_r': 39, 'len_c': 81, 'label': 'Tvmonitor'},
#  {'r': 0, 'c': 355, 'len_r': 103, 'len_c': 80, 'label': 'Bottle'},
#  {'r': 288, 'c': 186, 'len_r': 200, 'len_c': 89, 'label': 'Bottle'},
#  {'r': 360, 'c': 821, 'len_r': 104, 'len_c': 82, 'label': 'Bottle'},
#  {'r': 0, 'c': 333, 'len_r': 174, 'len_c': 73, 'label': 'Bottle'},
#  {'r': 311, 'c': 783, 'len_r': 230, 'len_c': 104, 'label': 'Bottle'},
#  {'r': 0, 'c': 188, 'len_r': 204, 'len_c': 79, 'label': 'Bottle'},
#  {'r': 72, 'c': 15, 'len_r': 104, 'len_c': 65, 'label': 'Bottle'},
#  {'r': 0, 'c': 834, 'len_r': 104, 'len_c': 60, 'label': 'Bottle'},
#  {'r': 245, 'c': 549, 'len_r': 38, 'len_c': 92, 'label': 'Tvmonitor'},
#  {'r': 432, 'c': 826, 'len_r': 102, 'len_c': 81, 'label': 'Bottle'},
#  {'r': 301, 'c': 580, 'len_r': 240, 'len_c': 86, 'label': 'Bottle'},
#  {'r': 30, 'c': 859, 'len_r': 74, 'len_c': 44, 'label': 'Bottle'},
#  {'r': 309, 'c': 721, 'len_r': 107, 'len_c': 50, 'label': 'Bottle'},
#  {'r': 283, 'c': 830, 'len_r': 242, 'len_c': 113, 'label': 'Bottle'},
#  {'r': 72, 'c': 706, 'len_r': 101, 'len_c': 35, 'label': 'Bottle'},
#  {'r': 432, 'c': 80, 'len_r': 83, 'len_c': 70, 'label': 'Bottle'},
#  {'r': 0, 'c': 290, 'len_r': 203, 'len_c': 80, 'label': 'Bottle'},
#  {'r': 144, 'c': 828, 'len_r': 104, 'len_c': 123, 'label': 'Tvmonitor'},
#  {'r': 432, 'c': 211, 'len_r': 81, 'len_c': 62, 'label': 'Bottle'},
#  {'r': 73, 'c': 838, 'len_r': 102, 'len_c': 109, 'label': 'Bottle'},
#  {'r': 366, 'c': 81, 'len_r': 170, 'len_c': 112, 'label': 'Bottle'},
#  {'r': 317, 'c': 681, 'len_r': 224, 'len_c': 97, 'label': 'Bottle'},
#  {'r': 288, 'c': 35, 'len_r': 104, 'len_c': 101, 'label': 'Bottle'},
#  {'r': 11, 'c': 724, 'len_r': 137, 'len_c': 47, 'label': 'Bottle'},
#  {'r': 73, 'c': 129, 'len_r': 102, 'len_c': 37, 'label': 'Bottle'},
#  {'r': 0, 'c': 426, 'len_r': 104, 'len_c': 105, 'label': 'Bottle'},
#  {'r': 0, 'c': 392, 'len_r': 203, 'len_c': 86, 'label': 'Bottle'},
#  {'r': 297, 'c': 340, 'len_r': 221, 'len_c': 82, 'label': 'Bottle'},
#  {'r': 0, 'c': 294, 'len_r': 104, 'len_c': 110, 'label': 'Bottle'},
#  {'r': 72, 'c': 488, 'len_r': 104, 'len_c': 76, 'label': 'Bottle'},
#  {'r': 298, 'c': 299, 'len_r': 219, 'len_c': 78, 'label': 'Bottle'},
#  {'r': 291, 'c': 169, 'len_r': 99, 'len_c': 98, 'label': 'Bottle'},
#  {'r': 296, 'c': 440, 'len_r': 222, 'len_c': 80, 'label': 'Bottle'},
#  {'r': 0, 'c': 78, 'len_r': 218, 'len_c': 92, 'label': 'Bottle'},
#  {'r': 368, 'c': 711, 'len_r': 157, 'len_c': 63, 'label': 'Bottle'},
#  {'r': 287, 'c': 134, 'len_r': 199, 'len_c': 89, 'label': 'Bottle'},
#  {'r': 72, 'c': 170, 'len_r': 104, 'len_c': 83, 'label': 'Bottle'},
#  {'r': 309, 'c': 590, 'len_r': 107, 'len_c': 55, 'label': 'Bottle'},
#  {'r': 288, 'c': 155, 'len_r': 97, 'len_c': 29, 'label': 'Bottle'},
#  {'r': 312, 'c': 519, 'len_r': 104, 'len_c': 54, 'label': 'Bottle'},
#  {'r': 0, 'c': 136, 'len_r': 208, 'len_c': 79, 'label': 'Bottle'},
#  {'r': 76, 'c': 256, 'len_r': 98, 'len_c': 49, 'label': 'Bottle'},
#  {'r': 300, 'c': 387, 'len_r': 215, 'len_c': 83, 'label': 'Bottle'},
#  {'r': 235, 'c': 799, 'len_r': 39, 'len_c': 131, 'label': 'Tvmonitor'},
#  {'r': 244, 'c': 641, 'len_r': 44, 'len_c': 81, 'label': 'Tvmonitor'},
#  {'r': 432, 'c': 908, 'len_r': 84, 'len_c': 44, 'label': 'Bottle'},
#  {'r': 379, 'c': 129, 'len_r': 85, 'len_c': 28, 'label': 'Bottle'},
#  {'r': 288, 'c': 224, 'len_r': 88, 'len_c': 40, 'label': 'Bottle'},
#  {'r': 289, 'c': 692, 'len_r': 103, 'len_c': 80, 'label': 'Bottle'},
#  {'r': 360, 'c': 145, 'len_r': 91, 'len_c': 39, 'label': 'Bottle'},
#  {'r': 12, 'c': 257, 'len_r': 92, 'len_c': 43, 'label': 'Bottle'},
#  {'r': 314, 'c': 377, 'len_r': 98, 'len_c': 61, 'label': 'Bottle'},
#  {'r': 346, 'c': 926, 'len_r': 70, 'len_c': 31, 'label': 'Bottle'},
#  {'r': 311, 'c': 735, 'len_r': 230, 'len_c': 99, 'label': 'Bottle'},
#  {'r': 270, 'c': 491, 'len_r': 236, 'len_c': 87, 'label': 'Bottle'},
#  {'r': 360, 'c': 863, 'len_r': 97, 'len_c': 57, 'label': 'Bottle'},
#  {'r': 316, 'c': 891, 'len_r': 217, 'len_c': 58, 'label': 'Bottle'},
#  {'r': 236, 'c': 556, 'len_r': 40, 'len_c': 127, 'label': 'Tvmonitor'}]

# %%
for i in range(len(result)):
    if result[i]['label'] == 'Bottle':
        target = image[result[i]['r']:result[i]['r']+result[i]['len_r'] , result[i]['c']:result[i]['c']+result[i]['len_c']]
        plt.imshow(target)
        plt.show()
